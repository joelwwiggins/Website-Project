# %%
import pandas as pd
import zipfile
import pymongo
from pymongo import MongoClient
import chardet
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# !python -m pip install --upgrade pip
# !python -m pip install pymongo[srv]

# %%
#Import data from CSV
jobs_import=pd.read_csv('data job posts.csv',encoding = "utf-8")
resume_import=pd.read_csv('UpdatedResumeDataSet - Copy.csv',engine="python", encoding="utf-8")

# %%
#Remove all non utf-8 characters
resume_import_clean=resume_import.replace('[^a-zA-Z\d\_.]+',' ',regex=True)
jobs_import_clean=jobs_import.replace('[^a-zA-Z\d\_.]+',' ',regex=True)

# %%
#Grab a few resumes
resume_desc=resume_import_clean['Resume']
resume_desc_shortlist=resume_desc.iloc[:4]
resume_desc_shortlist
# Out:
# 0    Skills Programming Languages Python pandas num...
# 1    Education Details May 2013 to May 2017 B.E UIT...
# 2    Areas of Interest Deep Learning Control System...
# 3    Skills R Python SAP HANA Tableau SAP HANA SQL ...
# Name: Resume, dtype: object

# %%
#Grab the jobs
post=jobs_import_clean['jobpost']
company=jobs_import_clean['Company']
post_shortlist=post[0:100]
post_shortlist
# Out:
# 0     AMERIA Investment Consulting Company JOB TITLE...
# 1     International Research Exchanges Board IREX TI...
# 2     Caucasus Environmental NGO Network CENN JOB TI...
# 3     Manoff Group JOB TITLE BCC Specialist POSITION...
# 4     Yerevan Brandy Company JOB TITLE Software Deve...
#                             ...
# 95    United Nations Development Programme JOB TITLE...
# 96    EU TACIS Project Support to the Development of...
# 97    Medecins Sans Frontieres Belgium JOB TITLE Eng...
# 98    Graduate School of Journalism Columbia Univers...
# 99    Vem Radio Station JOB TITLE Administrative Ass...
# Name: jobpost, Length: 100, dtype: object

# %%
#Generate cosign table
cos_list=pd.concat([resume_desc_shortlist,post_shortlist],ignore_index=False)
cos_list
# Out:
# 0     Skills Programming Languages Python pandas num...
# 1     Education Details May 2013 to May 2017 B.E UIT...
# 2     Areas of Interest Deep Learning Control System...
# 3     Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 0     AMERIA Investment Consulting Company JOB TITLE...
#                             ...
# 95    United Nations Development Programme JOB TITLE...
# 96    EU TACIS Project Support to the Development of...
# 97    Medecins Sans Frontieres Belgium JOB TITLE Eng...
# 98    Graduate School of Journalism Columbia Univers...
# 99    Vem Radio Station JOB TITLE Administrative Ass...
# Length: 104, dtype: object

# %%
#Generate cosine similarity table
cv = CountVectorizer()
count_matrix=cv.fit_transform(cos_list)
cos_sim_table=cosine_similarity(count_matrix)
cos_sim_table
#Convert to dataframe 
cos_sim_tabledf=pd.DataFrame(cos_sim_table)

# %%
#Pull in 4 resumes vs all job posting
limited_resumes=cos_sim_tabledf.iloc[0:4,4:]
limited_resumes
# Out:
#         4         5         6         7         8         9         10   \
# 0  0.604489  0.541603  0.529546  0.574443  0.382704  0.293086  0.432581
# 1  0.316574  0.265925  0.254875  0.280936  0.149504  0.132460  0.205775
# 2  0.329503  0.383072  0.327441  0.351268  0.310978  0.174499  0.315891
# 3  0.520224  0.497880  0.457364  0.537914  0.387329  0.248546  0.392008
#
#         11        12        13   ...       94        95        96        97   \
# 0  0.569603  0.486424  0.556336  ...  0.408553  0.571447  0.524396  0.596653
# 1  0.278234  0.214937  0.244120  ...  0.187037  0.261035  0.234621  0.267983
# 2  0.399860  0.358317  0.382106  ...  0.286481  0.380441  0.380921  0.423286
# 3  0.518741  0.415434  0.466550  ...  0.392548  0.513739  0.485926  0.554716
#
#         98        99        100       101       102       103
# 0  0.619890  0.584816  0.596834  0.332414  0.512000  0.363206
# 1  0.277208  0.263635  0.259875  0.141325  0.223222  0.165434
# ...

# %%
#Get company titles
company_titles=list(company[0:100])

# %%
# Change row and column name 
limited_resumes.columns=company_titles

# %%
limited_resumes["Names"]=["Joel","Mason","Anderson","Jake"]
limited_resumes.set_index("Names", inplace=True)

# %%
limited_resumes
# Out:
#           AMERIA Investment Consulting Company  \
# Names
# Joel                                  0.604489
# Mason                                 0.316574
# Anderson                              0.329503
# Jake                                  0.520224
#
#           International Research Exchanges Board IREX   \
# Names
# Joel                                          0.541603
# Mason                                         0.265925
# Anderson                                      0.383072
# Jake                                          0.497880
#
#           Caucasus Environmental NGO Network CENN   Manoff Group  \
# Names
# Joel                                      0.529546      0.574443
# Mason                                     0.254875      0.280936
# Anderson                                  0.327441      0.351268
# Jake                                      0.457364      0.537914
#
#           Yerevan Brandy Company  Boutique Appollo   \
# Names
# ...

# %%
d = limited_resumes.to_dict(orient ="index")
d
# Out:
# C:\Users\joelw\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.
# {'Joel': {'AMERIA Investment Consulting Company': 0.6044888229172193,
#   'International Research Exchanges Board IREX ': 0.5677609325714554,
#   'Caucasus Environmental NGO Network CENN ': 0.5295455582508979,
#   'Manoff Group': 0.5744426726585407,
#   'Yerevan Brandy Company': 0.4447364894299381,
#   'Boutique Appollo ': 0.2930855192842938,
#   'OSI Assistance Foundation Armenian Branch Office': 0.4325808449222052,
#   'American Embassy Yerevan ANNOUNCEMENT NUMBER 04 01': 0.5563358130018075,
#   'Institute for Sustainable Communities ISC ': 0.5877051454637098,
#   'Food Security Regional Cooperation and Stability Programme FRCS ': 0.5505036142614513,
#   'Teleplus LLC': 0.4617433532808107,
#   'NetCall Communications': 0.3336021900326181,
#   'SOC.Stockholm': 0.5802850401497296,
# ...

# %%
conn = "mongodb+srv://abc:1234@cluster0.7hm4r.mongodb.net/job_resume?retryWrites=true&w=majority"
client = pymongo.MongoClient(conn)
db = client.job_resume
# cos_sim=db.cos_sim
cos_sim.insert_one(d)

# %%
joel = pd.DataFrame([d["Joel"]]).T

# %%
joel.columns = ["value"]

# %%
joel.sort_values("value", ascending=False).head(10)
# Out:
#                                                        value
# ACDI VOCA                                           0.619973
# US Government OSI and the Civic Education Project   0.611126
# PLS RAMBOLL Management                              0.611046
# THE CENTER FOR COMMUNITY DIALOGUES AND INITIATI...  0.610821
# ACTR ACCELS                                         0.607895
# AMERIA Investment Consulting Company                0.604489
# Deloitte Emerging Markets                           0.599649
# EU TACIS Project Support to the Development of ...  0.596834
# Institute for Sustainable Communities ISC           0.587705
# European Project for Regional Development of Ar...  0.585804

# %%
def git_top10(name):
    d = db.collection.findall({})
#     d = limited_resumes.to_dict(orient ="index")
    df = pd.DataFrame([d[name]]).T
    df.columns = ["value"]
    return df.sort_values("value", ascending=False).head(10)

# %%
git_top10("Mason")
# Out:
# C:\Users\joelw\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#                                                        value
# AMERIA Investment Consulting Company                0.316574
# ACTR ACCELS                                         0.309892
# Institute for Sustainable Communities ISC           0.304581
# THE CENTER FOR COMMUNITY DIALOGUES AND INITIATI...  0.301363
# ACDI VOCA                                           0.301159
# Armenia TV                                          0.292510
# Manoff Group                                        0.280936
# Armenia School Connectivity Program                 0.279441
# Food Security Regional Cooperation and Stabilit...  0.277947
# International Research Exchanges Board IREX         0.277334
